# %%
# Import dependencies for the project
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns
import datetime
import time
#%matplotlib notebook

# %%
#Reading all csv files
cab_df= pd.read_csv('Cab_Data.csv')
customer_df=pd.read_csv('Customer_ID.csv')
transaction_df=pd.read_csv('Transaction_ID.csv')
city_df=pd.read_csv('City.csv')

# %%
cab_df.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
customer_df.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
transaction_df.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
city_df.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %% [markdown]
# # Merging the different csv files to one create a dataframe

# %% [markdown]
# Merging customer_df and transaction_df based on 'Customer ID' column

# %%
customer_transaction=customer_df.merge(transaction_df, how='inner', on='Customer ID',  left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
customer_transaction.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)  Transaction ID Payment_Mode
# 0        29290   Male   28               10813        10000011         Card
# 1        29290   Male   28               10813        10351127         Cash
# 2        29290   Male   28               10813        10412921         Card
# 3        27703   Male   27                9237        10000012         Card
# 4        27703   Male   27                9237        10320494         Card

# %% [markdown]
# Merging customer_transaction and cab_df based on 'Transaction ID' column

# %%
cab_customer=cab_df.merge(customer_transaction, how='inner', on='Transaction ID',  left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
cab_customer
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Gender  Age  \
# 0              30.45         370.95      313.6350        29290   Male   28
# 1              28.62         358.52      334.8540        27703   Male   27
# 2               9.04         125.20       97.6320        28712   Male   53
# 3              33.17         377.40      351.6020        28020   Male   23
# 4               8.73         114.62       97.7760        27182   Male   33
# ...              ...            ...           ...          ...    ...  ...
# 359387          4.80          69.24       63.3600        52392   Male   24
# 359388          8.40         113.75      106.8480        53286   Male   32
# 359389         27.75         437.07      349.6500        52265   Male   56
# 359390          8.80         146.19      114.0480        52175   Male   32
# 359391         12.76         191.58      177.6192        52917   Male   20
#
#         Income (USD/Month) Payment_Mode
# 0                    10813         Card
# 1                     9237         Card
# 2                    11242         Cash
# 3                    23327         Cash
# 4                     8536         Card
# ...                    ...          ...
# 359387               15651         Cash
# 359388                6528         Cash
# 359389                7966         Cash
# 359390                6423         Card
# 359391               11284         Card
#
# [359392 rows x 12 columns]

# %% [markdown]
# Merging cab_customer and city_df based on 'City' column

# %%
cab_data=cab_customer.merge(city_df, how='inner', on='City',  left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
cab_data
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Gender  Age  \
# 0              30.45         370.95      313.6350        29290   Male   28
# 1              28.62         358.52      334.8540        27703   Male   27
# 2               9.04         125.20       97.6320        28712   Male   53
# 3              33.17         377.40      351.6020        28020   Male   23
# 4               8.73         114.62       97.7760        27182   Male   33
# ...              ...            ...           ...          ...    ...  ...
# 359387          4.80          69.24       63.3600        52392   Male   24
# 359388          8.40         113.75      106.8480        53286   Male   32
# 359389         27.75         437.07      349.6500        52265   Male   56
# 359390          8.80         146.19      114.0480        52175   Male   32
# 359391         12.76         191.58      177.6192        52917   Male   20
#
#         Income (USD/Month) Payment_Mode Population      Users
# 0                    10813         Card   814,885     24,701
# 1                     9237         Card   814,885     24,701
# 2                    11242         Cash   814,885     24,701
# 3                    23327         Cash   814,885     24,701
# 4                     8536         Card   814,885     24,701
# ...                    ...          ...        ...        ...
# 359387               15651         Cash   418,859    127,001
# 359388                6528         Cash   418,859    127,001
# 359389                7966         Cash   418,859    127,001
# 359390                6423         Card   418,859    127,001
# 359391               11284         Card   418,859    127,001
#
# [359392 rows x 14 columns]

# %%
cab_data['Profit']= round(cab_data['Price Charged'] - cab_data['Cost of Trip'], 2)
cab_data
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Gender  Age  \
# 0              30.45         370.95      313.6350        29290   Male   28
# 1              28.62         358.52      334.8540        27703   Male   27
# 2               9.04         125.20       97.6320        28712   Male   53
# 3              33.17         377.40      351.6020        28020   Male   23
# 4               8.73         114.62       97.7760        27182   Male   33
# ...              ...            ...           ...          ...    ...  ...
# 359387          4.80          69.24       63.3600        52392   Male   24
# 359388          8.40         113.75      106.8480        53286   Male   32
# 359389         27.75         437.07      349.6500        52265   Male   56
# 359390          8.80         146.19      114.0480        52175   Male   32
# 359391         12.76         191.58      177.6192        52917   Male   20
#
#         Income (USD/Month) Payment_Mode Population      Users  Profit
# 0                    10813         Card   814,885     24,701    57.32
# 1                     9237         Card   814,885     24,701    23.67
# 2                    11242         Cash   814,885     24,701    27.57
# 3                    23327         Cash   814,885     24,701    25.80
# 4                     8536         Card   814,885     24,701    16.84
# ...                    ...          ...        ...        ...     ...
# 359387               15651         Cash   418,859    127,001     5.88
# 359388                6528         Cash   418,859    127,001     6.90
# 359389                7966         Cash   418,859    127,001    87.42
# 359390                6423         Card   418,859    127,001    32.14
# 359391               11284         Card   418,859    127,001    13.96
#
# [359392 rows x 15 columns]

# %% [markdown]
# # Data Cleaning:

# %% [markdown]
# Checking for null values in the data

# %%
cab_data.isnull()
# Out:
#         Transaction ID  Date of Travel  Company   City  KM Travelled  \
# 0                False           False    False  False         False
# 1                False           False    False  False         False
# 2                False           False    False  False         False
# 3                False           False    False  False         False
# 4                False           False    False  False         False
# ...                ...             ...      ...    ...           ...
# 359387           False           False    False  False         False
# 359388           False           False    False  False         False
# 359389           False           False    False  False         False
# 359390           False           False    False  False         False
# 359391           False           False    False  False         False
#
#         Price Charged  Cost of Trip  Customer ID  Gender    Age  \
# 0               False         False        False   False  False
# 1               False         False        False   False  False
# 2               False         False        False   False  False
# 3               False         False        False   False  False
# 4               False         False        False   False  False
# ...               ...           ...          ...     ...    ...
# 359387          False         False        False   False  False
# 359388          False         False        False   False  False
# 359389          False         False        False   False  False
# 359390          False         False        False   False  False
# 359391          False         False        False   False  False
#
#         Income (USD/Month)  Payment_Mode  Population  Users  Profit
# 0                    False         False       False  False   False
# 1                    False         False       False  False   False
# 2                    False         False       False  False   False
# 3                    False         False       False  False   False
# 4                    False         False       False  False   False
# ...                    ...           ...         ...    ...     ...
# 359387               False         False       False  False   False
# 359388               False         False       False  False   False
# 359389               False         False       False  False   False
# 359390               False         False       False  False   False
# 359391               False         False       False  False   False
#
# [359392 rows x 15 columns]

# %% [markdown]
# checking for nan if any present in the data

# %%
cab_data.isna().any()
# Out:
# Transaction ID        False
# Date of Travel        False
# Company               False
# City                  False
# KM Travelled          False
# Price Charged         False
# Cost of Trip          False
# Customer ID           False
# Gender                False
# Age                   False
# Income (USD/Month)    False
# Payment_Mode          False
# Population            False
# Users                 False
# Profit                False
# dtype: bool

# %% [markdown]
# checking for duplicate values in the data

# %%
cab_data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 359387    False
# 359388    False
# 359389    False
# 359390    False
# 359391    False
# Length: 359392, dtype: bool

# %%
# Converting Datetime 
cab_data['Date of Travel'] = pd.to_datetime(cab_data['Date of Travel'])
cab_data = cab_data.rename(columns = {'Date of Travel': 'Date Time'})
cab_data.head()
# Out:
#    Transaction ID                     Date Time   Company        City  \
# 0        10000011 1970-01-01 00:00:00.000042377  Pink Cab  ATLANTA GA
# 1        10000012 1970-01-01 00:00:00.000042375  Pink Cab  ATLANTA GA
# 2        10000013 1970-01-01 00:00:00.000042371  Pink Cab  ATLANTA GA
# 3        10000014 1970-01-01 00:00:00.000042376  Pink Cab  ATLANTA GA
# 4        10000015 1970-01-01 00:00:00.000042372  Pink Cab  ATLANTA GA
#
#    KM Travelled  Price Charged  Cost of Trip  Customer ID Gender  Age  \
# 0         30.45         370.95       313.635        29290   Male   28
# 1         28.62         358.52       334.854        27703   Male   27
# 2          9.04         125.20        97.632        28712   Male   53
# 3         33.17         377.40       351.602        28020   Male   23
# 4          8.73         114.62        97.776        27182   Male   33
#
#    Income (USD/Month) Payment_Mode Population     Users  Profit
# 0               10813         Card   814,885    24,701    57.32
# 1                9237         Card   814,885    24,701    23.67
# 2               11242         Cash   814,885    24,701    27.57
# 3               23327         Cash   814,885    24,701    25.80
# 4                8536         Card   814,885    24,701    16.84

# %%
#Splitting Date from the Date Time column
cab_data['Date'] = pd.to_datetime(cab_data['Date Time']).dt.date

# %%
cab_data.head()
# Out:
#    Transaction ID                     Date Time   Company        City  \
# 0        10000011 1970-01-01 00:00:00.000042377  Pink Cab  ATLANTA GA
# 1        10000012 1970-01-01 00:00:00.000042375  Pink Cab  ATLANTA GA
# 2        10000013 1970-01-01 00:00:00.000042371  Pink Cab  ATLANTA GA
# 3        10000014 1970-01-01 00:00:00.000042376  Pink Cab  ATLANTA GA
# 4        10000015 1970-01-01 00:00:00.000042372  Pink Cab  ATLANTA GA
#
#    KM Travelled  Price Charged  Cost of Trip  Customer ID Gender  Age  \
# 0         30.45         370.95       313.635        29290   Male   28
# 1         28.62         358.52       334.854        27703   Male   27
# 2          9.04         125.20        97.632        28712   Male   53
# 3         33.17         377.40       351.602        28020   Male   23
# 4          8.73         114.62        97.776        27182   Male   33
#
#    Income (USD/Month) Payment_Mode Population     Users  Profit        Date
# 0               10813         Card   814,885    24,701    57.32  1970-01-01
# 1                9237         Card   814,885    24,701    23.67  1970-01-01
# 2               11242         Cash   814,885    24,701    27.57  1970-01-01
# 3               23327         Cash   814,885    24,701    25.80  1970-01-01
# 4                8536         Card   814,885    24,701    16.84  1970-01-01

# %%
cab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      359392 non-null  int64
#  1   Date Time           359392 non-null  datetime64[ns]
#  2   Company             359392 non-null  object
#  3   City                359392 non-null  object
#  4   KM Travelled        359392 non-null  float64
#  5   Price Charged       359392 non-null  float64
#  6   Cost of Trip        359392 non-null  float64
#  7   Customer ID         359392 non-null  int64
#  8   Gender              359392 non-null  object
#  9   Age                 359392 non-null  int64
#  10  Income (USD/Month)  359392 non-null  int64
#  11  Payment_Mode        359392 non-null  object
#  12  Population          359392 non-null  object
#  13  Users               359392 non-null  object
#  14  Profit              359392 non-null  float64
#  15  Date                359392 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(4), object(7)
# memory usage: 46.6+ MB

# %%
cab_data.describe()
# Out:
#        Transaction ID   KM Travelled  Price Charged   Cost of Trip  \
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07      22.567254     423.443311     286.190113
# std      1.268058e+05      12.233526     274.378911     157.993661
# min      1.000001e+07       1.900000      15.600000      19.000000
# 25%      1.011081e+07      12.000000     206.437500     151.200000
# 50%      1.022104e+07      22.440000     386.360000     282.480000
# 75%      1.033094e+07      32.960000     583.660000     413.683200
# max      1.044011e+07      48.000000    2048.030000     691.200000
#
#          Customer ID            Age  Income (USD/Month)         Profit
# count  359392.000000  359392.000000       359392.000000  359392.000000
# mean    19191.652115      35.336705        15048.822937     137.253197
# std     21012.412463      12.594234         7969.409482     160.311840
# min         1.000000      18.000000         2000.000000    -220.060000
# 25%      2705.000000      25.000000         8424.000000      28.010000
# 50%      7459.000000      33.000000        14685.000000      81.960000
# 75%     36078.000000      42.000000        21035.000000     190.030000
# max     60000.000000      65.000000        35000.000000    1463.970000

# %% [markdown]
# # Grouping the Dataset based on the cab company for further analysis

# %%
pink_cab = cab_data[cab_data['Company'] == 'Pink Cab']
pink_cab
# Out:
#         Transaction ID                     Date Time   Company           City  \
# 0             10000011 1970-01-01 00:00:00.000042377  Pink Cab     ATLANTA GA
# 1             10000012 1970-01-01 00:00:00.000042375  Pink Cab     ATLANTA GA
# 2             10000013 1970-01-01 00:00:00.000042371  Pink Cab     ATLANTA GA
# 3             10000014 1970-01-01 00:00:00.000042376  Pink Cab     ATLANTA GA
# 4             10000015 1970-01-01 00:00:00.000042372  Pink Cab     ATLANTA GA
# ...                ...                           ...       ...            ...
# 359159        10437610 1970-01-01 00:00:00.000043106  Pink Cab  WASHINGTON DC
# 359160        10437611 1970-01-01 00:00:00.000043465  Pink Cab  WASHINGTON DC
# 359161        10437612 1970-01-01 00:00:00.000043107  Pink Cab  WASHINGTON DC
# 359162        10437614 1970-01-01 00:00:00.000043102  Pink Cab  WASHINGTON DC
# 359163        10437615 1970-01-01 00:00:00.000043105  Pink Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID  Gender  Age  \
# 0              30.45         370.95       313.635        29290    Male   28
# 1              28.62         358.52       334.854        27703    Male   27
# 2               9.04         125.20        97.632        28712    Male   53
# 3              33.17         377.40       351.602        28020    Male   23
# 4               8.73         114.62        97.776        27182    Male   33
# ...              ...            ...           ...          ...     ...  ...
# 359159         13.56         184.19       135.600        51142  Female   40
# 359160         29.68         388.08       302.736        52754  Female   29
# 359161         28.50         369.04       310.650        53039    Male   37
# 359162         16.10         194.17       162.610        51766    Male   18
# 359163         22.20         287.46       244.200        51996    Male   36
#
#         Income (USD/Month) Payment_Mode Population      Users  Profit  \
# 0                    10813         Card   814,885     24,701    57.32
# 1                     9237         Card   814,885     24,701    23.67
# 2                    11242         Cash   814,885     24,701    27.57
# 3                    23327         Cash   814,885     24,701    25.80
# 4                     8536         Card   814,885     24,701    16.84
# ...                    ...          ...        ...        ...     ...
# 359159                3122         Card   418,859    127,001    48.59
# 359160               19676         Card   418,859    127,001    85.34
# 359161               22765         Card   418,859    127,001    58.39
# 359162               12364         Cash   418,859    127,001    31.56
# 359163               12905         Cash   418,859    127,001    43.26
#
#               Date
# 0       1970-01-01
# 1       1970-01-01
# 2       1970-01-01
# 3       1970-01-01
# 4       1970-01-01
# ...            ...
# 359159  1970-01-01
# 359160  1970-01-01
# 359161  1970-01-01
# 359162  1970-01-01
# 359163  1970-01-01
#
# [84711 rows x 16 columns]

# %%
yellow_cab = cab_data[cab_data['Company'] == 'Yellow Cab']
yellow_cab
# Out:
#         Transaction ID                     Date Time     Company  \
# 6             10000384 1970-01-01 00:00:00.000042371  Yellow Cab
# 7             10000385 1970-01-01 00:00:00.000042378  Yellow Cab
# 8             10000386 1970-01-01 00:00:00.000042372  Yellow Cab
# 9             10000387 1970-01-01 00:00:00.000042375  Yellow Cab
# 10            10000388 1970-01-01 00:00:00.000042376  Yellow Cab
# ...                ...                           ...         ...
# 359387        10440101 1970-01-01 00:00:00.000043108  Yellow Cab
# 359388        10440104 1970-01-01 00:00:00.000043104  Yellow Cab
# 359389        10440105 1970-01-01 00:00:00.000043105  Yellow Cab
# 359390        10440106 1970-01-01 00:00:00.000043105  Yellow Cab
# 359391        10440107 1970-01-01 00:00:00.000043102  Yellow Cab
#
#                  City  KM Travelled  Price Charged  Cost of Trip  Customer ID  \
# 6          ATLANTA GA         33.93        1341.17      464.1624        27602
# 7          ATLANTA GA         42.18        1412.06      516.2832        27594
# 8          ATLANTA GA         10.60         364.62      132.2880        27884
# 9          ATLANTA GA         26.75         838.00      333.8400        28533
# 10         ATLANTA GA         46.02        1540.61      596.4192        29039
# ...               ...           ...            ...           ...          ...
# 359387  WASHINGTON DC          4.80          69.24       63.3600        52392
# 359388  WASHINGTON DC          8.40         113.75      106.8480        53286
# 359389  WASHINGTON DC         27.75         437.07      349.6500        52265
# 359390  WASHINGTON DC          8.80         146.19      114.0480        52175
# 359391  WASHINGTON DC         12.76         191.58      177.6192        52917
#
#        Gender  Age  Income (USD/Month) Payment_Mode Population      Users  \
# 6        Male   23                8542         Card   814,885     24,701
# 7        Male   28                3901         Cash   814,885     24,701
# 8        Male   32               13505         Cash   814,885     24,701
# 9        Male   39               28386         Cash   814,885     24,701
# 10       Male   35               17761         Card   814,885     24,701
# ...       ...  ...                 ...          ...        ...        ...
# 359387   Male   24               15651         Cash   418,859    127,001
# 359388   Male   32                6528         Cash   418,859    127,001
# 359389   Male   56                7966         Cash   418,859    127,001
# 359390   Male   32                6423         Card   418,859    127,001
# 359391   Male   20               11284         Card   418,859    127,001
#
#         Profit        Date
# 6       877.01  1970-01-01
# 7       895.78  1970-01-01
# 8       232.33  1970-01-01
# 9       504.16  1970-01-01
# 10      944.19  1970-01-01
# ...        ...         ...
# 359387    5.88  1970-01-01
# 359388    6.90  1970-01-01
# 359389   87.42  1970-01-01
# 359390   32.14  1970-01-01
# 359391   13.96  1970-01-01
#
# [274681 rows x 16 columns]

# %%
stat_agg_df=cab_data.groupby('Company').agg({'Profit' : ['mean', 'median', 'var', 'std', 'sem']})
stat_agg_df
# Out:
#                 Profit
#                   mean median           var         std       sem
# Company
# Pink Cab     62.652176   41.5   6020.268633   77.590390  0.266586
# Yellow Cab  160.259984  102.0  29523.429607  171.823833  0.327845

# %% [markdown]
# # Hypothesis to test:
#
# #GENDER:
#
# . Does gender play any role in choosing a cab compnay over other?
#
# . Does the km travelled differ between cab companies based on gender?
#
# . Does gender affect the overall profit of the cab companies?
#
# #COLOR OF CAB:
#
# . Does color of the cab change the preference of the users?
#
# . Does color of the cab influence the profit of the companies?
#
# #LOCATION OF THE COMPANY:
#
# . Does location determine a companies overall profit/loss?
#
# . Does location have any effect on the price charged and cost of the trip?
#
# . Is location a factor for choosing a cab company?
#
# #INCOME/PAYMENT METHOD:
#
# . Is income of the users relate to the profit/loss of a cab company?
#
# . Does payment method have any influence on selecting a specific cab company?

# %% [markdown]
# # GENDER BASED ANALYSIS:

# %%
gender_df = cab_data.groupby(['Gender'])

# %%
gender_counts=gender_df.count()["Company"]
gender_counts_df=pd.DataFrame(gender_counts)
gender_counts_df
# Out:
#         Company
# Gender
# Female   153480
# Male     205912

# %%
total_count= cab_data['Gender'].count()
gender_percent=(gender_counts/total_count) * 100
gender_percent_df=pd.DataFrame(gender_percent)
gender_percent_df
# Out:
#           Company
# Gender
# Female  42.705458
# Male    57.294542

# %%
colors = ['hotpink', 'slateblue']
plt.pie(gender_percent_df["Company"], 
        colors=colors, 
        labels=gender_percent_df.index, 
        autopct="%1.1f%%", 
        startangle=180)
plt.show()

# %% [markdown]
# The overall percentage of the Male and Female users included in this analysisn is 57.3 and 42.7. There are more male users compared to the female users.

# %%
pink_gender=pink_cab. groupby(['Gender'])
pink_gcount=pd.DataFrame(pink_gender['Users'].count())
pink_gpercent=pd.DataFrame((pink_gcount/total_count) * 100)
pink_gpercent
# Out:
#             Users
# Gender
# Female  10.428724
# Male    13.141917

# %%
yellow_gender=yellow_cab. groupby(['Gender'])
yellow_gcount=pd.DataFrame(yellow_gender['Users'].count())
yellow_gcount
yellow_gpercent=pd.DataFrame((yellow_gcount/total_count) * 100)
yellow_gpercent
# Out:
#             Users
# Gender
# Female  32.276734
# Male    44.152624

# %% [markdown]
# Gender comparison based on the cab company signifies that the both Male and Female users preferred Yellow cab company compared to the Pink cab company. Male users were significantly higher compared to female users for both companies.

# %%
colors = ['lightpink', 'orchid']
plt.pie(pink_gpercent["Users"], 
        labels=pink_gpercent.index, 
        colors=colors,
        autopct="%1.1f%%", 
        startangle=180)
plt.show()

# %% [markdown]
# The pie chart shows that among the pink cab users 55.8% were male and 44.2% were female.

# %%
colors =['khaki', 'gold']
plt.pie(yellow_gpercent["Users"], 
        labels=yellow_gpercent.index, 
        colors =colors, 
        autopct="%1.1f%%", 
        startangle=180)
plt.show()

# %% [markdown]
# The pie chart shows that among the yellow cab users 57.8% were male and 42.2% were female.

# %%
total_profit=cab_data['Profit'].sum()
print(total_profit)
profit_data=cab_data.groupby('Company')['Profit'].sum()
profit_data
# Out:
# 49327701.099999994
# Company
# Pink Cab       5307328.51
# Yellow Cab    44020372.59
# Name: Profit, dtype: float64

# %% [markdown]
# The yellow cab contributed close to 89.2% to the overall profit compared to the pink cab company whoch contributed only a 10.7% overall.

# %%
yellow_profit=yellow_cab.groupby('Gender')['Profit'].sum()
yellow_profitpercent=pd.DataFrame((yellow_profit/total_profit) * 100)
yellow_profitpercent
# Out:
#            Profit
# Gender
# Female  36.757071
# Male    52.483602

# %%
pink_profit=pink_cab.groupby('Gender')['Profit'].sum()
pink_profitpercent=pd.DataFrame((pink_profit/total_profit) * 100)
pink_profitpercent
# Out:
#           Profit
# Gender
# Female  4.724593
# Male    6.034734

# %%
df= cab_data.groupby(['Company', 'Gender']).Profit.sum()
df=df.reset_index()
def barPerc(df,xVar,ax):
    # 1. how many X categories
    ##   check for NaN and remove
    numX=len([x for x in df[xVar].unique() if x==x])

    # 2. The bars are created in hue order, organize them
    bars = ax.patches
    ## 2a. For each X variable
    for ind in range(numX):
        ## 2b. Get every hue bar
        ##     ex. 8 X categories, 4 hues =>
        ##    [0, 8, 16, 24] are hue bars for 1st X category
        hueBars=bars[ind:][::numX]
        ## 2c. Get the total height (for percentages)
        total = sum([x.get_height() for x in hueBars])

        # 3. Print the percentage on the bars
        for bar in hueBars:
            ax.text(bar.get_x() + bar.get_width()/2.,
                    bar.get_height(),
                    f'{bar.get_height()/total:0.1%}',
                    ha="center",va="bottom")
ax=sns.barplot( 
    x='Company', 
    y='Profit', 
    hue='Gender',
    data=df
    )

ax.set(ylabel='Pofit', title='Gender based Profit of Cab Companies')
barPerc(df, 'Gender', ax)
# add annotations
#for c in ax.containers:
    
    # custom label calculates percent and add an empty string so 0 value bars don't have a number
    #labels = [f'{h/cab_data.Gender.count()*100:0.1f}%' if (h := v.get_height()) > 0 else '' for v in c]
    
    #ax.bar_label(c, labels=labels, label_type='edge')

plt.show()

# %%
total_km=cab_data['KM Travelled'].sum()
print(total_km)
km_data=cab_data.groupby('Company')['KM Travelled'].sum()
km_data
# Out:
# 8110490.580000001
# Company
# Pink Cab      1911073.11
# Yellow Cab    6199417.47
# Name: KM Travelled, dtype: float64

# %%
pink_km=pd.DataFrame(pink_cab.groupby('Gender')['KM Travelled'].sum().reset_index())
pink_km
# Out:
#    Gender  KM Travelled
# 0  Female     846431.28
# 1    Male    1064641.83

# %%
yellow_km=pd.DataFrame(yellow_cab.groupby('Gender')['KM Travelled'].sum().reset_index())
yellow_km
# Out:
#    Gender  KM Travelled
# 0  Female    2620127.59
# 1    Male    3579289.88

# %%
df1 = pd.merge(pink_km, yellow_km, on='Gender', suffixes=('_pink', '_yellow'))


df1
# Out:
#    Gender  KM Travelled_pink  KM Travelled_yellow
# 0  Female          846431.28           2620127.59
# 1    Male         1064641.83           3579289.88

# %%
color=['lightpink', 'gold']
df1.plot.bar(x= 'Gender', color=color)
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('Gender based difference in Distance Travelled')
plt.show()

# %%
pink_city= pink_cab.groupby(['City']).Profit.sum().reset_index()
pink_city
# Out:
#               City      Profit
# 0       ATLANTA GA    96050.01
# 1        AUSTIN TX   147445.16
# 2        BOSTON MA   262001.66
# 3       CHICAGO IL   318722.35
# 4        DALLAS TX    24730.12
# 5        DENVER CO    40585.04
# 6   LOS ANGELES CA  1125731.72
# 7         MIAMI FL   162301.20
# 8     NASHVILLE TN    64284.61
# 9      NEW YORK NY  1511474.79
# 10   ORANGE COUNTY   101995.71
# 11      PHOENIX AZ    35596.33
# 12   PITTSBURGH PA    17107.57
# 13   SACRAMENTO CA    55323.87
# 14    SAN DIEGO CA   637890.19
# 15      SEATTLE WA   112781.45
# 16  SILICON VALLEY   340250.77
# 17       TUCSON AZ    59289.64
# 18   WASHINGTON DC   193766.32

# %%
yellow_city= yellow_cab.groupby(['City']).Profit.sum().reset_index()

yellow_city
# Out:
#               City       Profit
# 0       ATLANTA GA    746382.57
# 1        AUSTIN TX    379255.77
# 2        BOSTON MA   1506717.26
# 3       CHICAGO IL   3068590.79
# 4        DALLAS TX   1104003.21
# 5        DENVER CO    357000.04
# 6   LOS ANGELES CA   3285976.44
# 7         MIAMI FL    595999.98
# 8     NASHVILLE TN     85247.51
# 9      NEW YORK NY  26451081.44
# 10   ORANGE COUNTY    355006.10
# 11      PHOENIX AZ    157344.41
# 12   PITTSBURGH PA     68058.17
# 13   SACRAMENTO CA     62002.10
# 14    SAN DIEGO CA    949273.59
# 15      SEATTLE WA    491903.43
# 16  SILICON VALLEY    976454.71
# 17       TUCSON AZ     80971.17
# 18   WASHINGTON DC   3299103.90

# %%
city_df=pd.merge(pink_city, yellow_city, on='City', suffixes=('_pink', '_yellow'))
city_df
# Out:
#               City  Profit_pink  Profit_yellow
# 0       ATLANTA GA     96050.01      746382.57
# 1        AUSTIN TX    147445.16      379255.77
# 2        BOSTON MA    262001.66     1506717.26
# 3       CHICAGO IL    318722.35     3068590.79
# 4        DALLAS TX     24730.12     1104003.21
# 5        DENVER CO     40585.04      357000.04
# 6   LOS ANGELES CA   1125731.72     3285976.44
# 7         MIAMI FL    162301.20      595999.98
# 8     NASHVILLE TN     64284.61       85247.51
# 9      NEW YORK NY   1511474.79    26451081.44
# 10   ORANGE COUNTY    101995.71      355006.10
# 11      PHOENIX AZ     35596.33      157344.41
# 12   PITTSBURGH PA     17107.57       68058.17
# 13   SACRAMENTO CA     55323.87       62002.10
# 14    SAN DIEGO CA    637890.19      949273.59
# 15      SEATTLE WA    112781.45      491903.43
# 16  SILICON VALLEY    340250.77      976454.71
# 17       TUCSON AZ     59289.64       80971.17
# 18   WASHINGTON DC    193766.32     3299103.90

# %%
color=['orchid', 'gold']
city_df.plot.bar(x= 'City', color=color)

plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.title('Profit based on City')
plt.figure(figsize=(14,10))

plt.show()
